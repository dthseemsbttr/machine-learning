# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('train_1.csv')

# %%
df
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 0     11809          27    3.0  115.027311         NaN           10.0      4
# 1      3013          22    1.0   39.832524   23.169223            8.0      7
# 2      8215           1    3.0   78.342215   47.671972           10.0      2
# 3      2352           1    1.0   40.409907         NaN            1.0     10
# 4     13866          94    2.0   64.285067   38.562517            9.0     16
# ...     ...         ...    ...         ...         ...            ...    ...
# 9995   1260          61    2.0   49.090728   33.272626            6.0      3
# 9996  16265          27    2.0   64.307684   37.038420            9.0     13
# 9997   2795         178    1.0   29.648057   16.555363            5.0      3
# 9998  14561          21    1.0   32.330292   22.326870            5.0      3
# 9999   7202          94    1.0   35.815476   22.301367            6.0      9
#
# ...

# %%
rooms_count = df['Rooms'].value_counts()
plt.pie(rooms_count, labels=rooms_count.index, explode=[0.2]+[0]*(len(rooms_count)-1))
# Out:
# ([<matplotlib.patches.Wedge at 0x1bb86834640>,
# ...
#  [Text(0.44803575625188097, 1.220354031058121, '2.0'),
#   Text(-0.9855388601001231, -0.4885828028415964, '1.0'),
#   Text(0.7542604996705474, -0.8006816462469565, '3.0'),
#   Text(1.0976069992746822, -0.07251810217613464, '4.0'),
#   Text(1.0999042472054479, -0.014513682489880855, '5.0'),
#   Text(1.099986103898947, -0.005529125538024876, '0.0'),
#   Text(1.099998045920999, -0.002073395761555657, '10.0'),
#   Text(1.099999511505639, -0.0010366712863557467, '19.0'),
#   Text(1.099999945734177, -0.00034552106780094655, '6.0')])

# %%
plt.hist(df['Price'])
# Out:
# (array([ 917., 2792., 3168., 1434.,  731.,  437.,  254.,  154.,   72.,
#           41.]),
#  array([ 59174.77802758, 116580.64688182, 173986.51573605, 231392.38459029,
#         288798.25344453, 346204.12229876, 403609.991153  , 461015.86000724,
#         518421.72886147, 575827.59771571, 633233.46656995]),
#  <a list of 10 Patch objects>)

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 10))
ax[0,0].scatter(x = df['Price'], y = df['Rooms'])
ax[0,1].scatter(x = df['Price'], y = df['Square'])
ax[1,0].scatter(x = df['Price'], y = df['HouseFloor'])
ax[1,1].scatter(x = df['Price'], y = df['HouseYear'])

# %%
sns.kdeplot(df['Price'])

# %%
sns.kdeplot(df['Price'], df['HouseFloor'])
plt.ylim(0, 40)
# Out:
# (0.0, 40.0)

# %%
plt.boxplot(df['Square'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1bb86ae3520>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1bb86ae3be0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1bb86ae31c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1bb86aed2e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1bb86aed5e0>],
#  'means': []}

# %%
sns.pairplot(df[['Rooms', 'Square', 'HouseFloor', 'HouseYear', 'Price']]).map_lower(sns.kdeplot, levels=20)

# %%
sns.heatmap(df[['Rooms', 'Square', 'HouseFloor', 'HouseYear', 'Price']].corr())

# %%
sns.jointplot(df['Square'], df['Price'])

# %%
sns.violinplot(df['Rooms'], df['Price'])
