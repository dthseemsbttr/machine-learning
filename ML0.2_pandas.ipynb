# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Количество и названия константных и уникальных полей
for i in df:
    print(df[i].value_counts())
# Out:
# 1      1
# 599    1
# 588    1
# 589    1
# 590    1
#       ..
# 301    1
# 302    1
# 303    1
# 304    1
# 891    1
# Name: PassengerId, Length: 891, dtype: int64
# 0    549
# 1    342
# Name: Survived, dtype: int64
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64
# Braund, Mr. Owen Harris                     1
# Boulos, Mr. Hanna                           1
# Frolicher-Stehli, Mr. Maxmillian            1
# Gilinski, Mr. Eliezer                       1
# Murdlin, Mr. Joseph                         1
#                                            ..
# Kelly, Miss. Anna Katherine "Annie Kate"    1
# McCoy, Mr. Bernard                          1
# Johnson, Mr. William Cahoone Jr             1
# Keane, Miss. Nora A                         1
# Dooley, Mr. Patrick                         1
# Name: Name, Length: 891, dtype: int64
# male      577
# female    314
# Name: Sex, dtype: int64
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# ...

# %%
df = df.drop(['Cabin', 'Ticket'], axis = 1)

# %%
df['Age'] = 1912 - df['Age']

# %%
df.columns = ['id Пассажира', 'Выжил', 'Класс', 'Имя', 'Пол', 'Год Рождения', 'Сибсп', 'Парч', 'Фейр', 'Тип']

# %%
df
# Out:
#      id Пассажира  Выжил  Класс  \
# 0               1      0      3
# 1               2      1      1
# 2               3      1      3
# 3               4      1      1
# 4               5      0      3
# ..            ...    ...    ...
# 886           887      0      2
# 887           888      1      1
# 888           889      0      3
# 889           890      1      1
# 890           891      0      3
#
#                                                    Имя     Пол  Год Рождения  \
# 0                              Braund, Mr. Owen Harris    male        1890.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female        1874.0
# 2                               Heikkinen, Miss. Laina  female        1886.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female        1877.0
# 4                             Allen, Mr. William Henry    male        1877.0
# ..                                                 ...     ...           ...
# ...

# %%
df.isna().sum()
# Out:
# id Пассажира      0
# Выжил             0
# Класс             0
# Имя               0
# Пол               0
# Год Рождения    177
# Сибсп             0
# Парч              0
# Фейр              0
# Тип               2
# dtype: int64

# %%
df['Год Рождения'].fillna(df['Год Рождения'].mean())
# Out:
# 0      1890.000000
# 1      1874.000000
# 2      1886.000000
# 3      1877.000000
# 4      1877.000000
#           ...
# 886    1885.000000
# 887    1893.000000
# 888    1882.300882
# 889    1886.000000
# 890    1880.000000
# Name: Год Рождения, Length: 891, dtype: float64

# %%
df['Тип'] = df['Тип'].fillna(df['Тип'].mode())

# %%
df.to_csv('Titanic_df.csv')

# %%
df = pd.read_csv('Titanic_df.csv', index_col=0)

# %%
df
# Out:
#      id Пассажира  Выжил  Класс  \
# 0               1      0      3
# 1               2      1      1
# 2               3      1      3
# 3               4      1      1
# 4               5      0      3
# ..            ...    ...    ...
# 886           887      0      2
# 887           888      1      1
# 888           889      0      3
# 889           890      1      1
# 890           891      0      3
#
#                                                    Имя     Пол  Год Рождения  \
# 0                              Braund, Mr. Owen Harris    male        1890.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female        1874.0
# 2                               Heikkinen, Miss. Laina  female        1886.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female        1877.0
# 4                             Allen, Mr. William Henry    male        1877.0
# ..                                                 ...     ...           ...
# ...
